# %% [markdown]
# # Feature Extraction using the PyRadiomics toolbox in Python

# %% [markdown]
# ### Imports

# %%
import os  # needed navigate the system to get the input data
import pandas as pd
from pathlib import Path


import radiomics
from radiomics import featureextractor  # This module is used for interaction with pyradiomics

# %% [markdown]
# ### Load the label data for each sample

# %%
# Load the labels
dataset_folder = Path(os.getcwd()+'/dataset')
label = pd.read_excel(dataset_folder/Path('Pretreat-MetsToBrain-Masks_clin_20230918.xlsx'),sheet_name='Data')

# Select and process the labels
# label = label[['BraTS_MET_ID', 'Death']].dropna(axis=0, subset=['Death'])
label = label.dropna(axis=0, subset=['Death'])
label.Death = label.Death.astype(int)

# %% [markdown]
# ### Instantiating the extractor

# %% [markdown]
# ##### Important step to define the parms file version

# %%
# params_file_name = 'default_params'
params_file_name = 'params_1'

image_types = ('original', 'log-sigma', 'wavelet')

print(f"Setup for parameters: {params_file_name} and image types: {image_types}")
# Out:
# Setup for parameters: params_1 and image types: ('original', 'log-sigma', 'wavelet')

# %%
# Location of the parameter file
paramPath = os.path.join('params', params_file_name+'.yaml')
print('Parameter file, absolute path:', os.path.abspath(paramPath))

# Instantiate the extractor with parameters file
extractor = featureextractor.RadiomicsFeatureExtractor(paramPath)

print('Extraction parameters:\n\t', extractor.settings)
print('Enabled filters:\n\t', extractor.enabledImagetypes)
print('Enabled features:\n\t', extractor.enabledFeatures)
# Out:
# Parameter file, absolute path: /Users/stelios/workspace/stelios/pyradiomics/v2/params/params_1.yaml
# Extraction parameters:
# 	 {'minimumROIDimensions': 2, 'minimumROISize': None, 'normalize': True, 'normalizeScale': 100, 'removeOutliers': None, 'resampledPixelSpacing': [2, 2, 2], 'interpolator': 'sitkBSpline', 'preCrop': False, 'padDistance': 5, 'distances': [1], 'force2D': False, 'force2Ddimension': 0, 'resegmentRange': None, 'label': 1, 'additionalInfo': True, 'binWidth': 5, 'voxelArrayShift': 300}
# Enabled filters:
# 	 {'Original': {}, 'LoG': {'sigma': [2.0, 3.0, 4.0, 5.0]}, 'Wavelet': {}}
# Enabled features:
# 	 {'shape': None, 'firstorder': None, 'glcm': ['Autocorrelation', 'JointAverage', 'ClusterProminence', 'ClusterShade', 'ClusterTendency', 'Contrast', 'Correlation', 'DifferenceAverage', 'DifferenceEntropy', 'DifferenceVariance', 'JointEnergy', 'JointEntropy', 'Imc1', 'Imc2', 'Idm', 'Idmn', 'Id', 'Idn', 'InverseVariance', 'MaximumProbability', 'SumEntropy', 'SumSquares'], 'glrlm': None, 'glszm': None, 'gldm': None, 'ngtdm': None}

# %% [markdown]
# ### Setting up data and Feature Extraction

# %%
rootdir = dataset_folder/Path("dataset_to_process") # directory to store data we are interested in
features = [] # List of extracted features

for x in os.walk(rootdir):
    if 'BraTS' in x[0]:
        # sample_dir = /path/to/repo/v2/dataset/dataset_to_process/BraTS-MET-XXXXX-YYY
        sample_dir = x[0]

        # sample_file_base_name = BraTS-MET-XXXXX-YYY
        sample_file_base_name = sample_dir.split('/')[-1]

        # BraTS_MET_ID = XXXXX : int
        BraTS_MET_ID = int(sample_file_base_name.split('-')[-2])
        print(f"Fetching sample with ID: {BraTS_MET_ID}")

        # Get Image paths
        imagePath = os.path.join(sample_dir, sample_file_base_name+'-t2w.nii')
        maskPath = os.path.join(sample_dir, sample_file_base_name+'-seg.nii')

        # Feature extraction with pyradiomics
        print(f"Extracting features for sample: {sample_file_base_name}")
        results = extractor.execute(imagePath, maskPath)

        # Keep only specific features 
        temp = {k:v for k, v in results.items() if k.startswith(image_types)}
        temp.update({'BraTS_MET_ID':BraTS_MET_ID})
        features.append(temp)
# Out:
# Fetching sample with ID: 86
# Extracting features for sample: BraTS-MET-00086-000
# Fetching sample with ID: 284
# Extracting features for sample: BraTS-MET-00284-000
# Fetching sample with ID: 290
# Extracting features for sample: BraTS-MET-00290-000
# Fetching sample with ID: 247
# Extracting features for sample: BraTS-MET-00247-000
# Fetching sample with ID: 253
# Extracting features for sample: BraTS-MET-00253-000
# Fetching sample with ID: 119
# Extracting features for sample: BraTS-MET-00119-000
# Fetching sample with ID: 131
# Extracting features for sample: BraTS-MET-00131-000
# Fetching sample with ID: 125
# Extracting features for sample: BraTS-MET-00125-000
# Fetching sample with ID: 124
# Extracting features for sample: BraTS-MET-00124-000
# Fetching sample with ID: 130
# Extracting features for sample: BraTS-MET-00130-000
# Fetching sample with ID: 118
# Extracting features for sample: BraTS-MET-00118-000
# Fetching sample with ID: 252
# Extracting features for sample: BraTS-MET-00252-000
# Fetching sample with ID: 291
# Extracting features for sample: BraTS-MET-00291-000
# Fetching sample with ID: 285
# Extracting features for sample: BraTS-MET-00285-000
# Fetching sample with ID: 293
# Extracting features for sample: BraTS-MET-00293-000
# Fetching sample with ID: 278
# Extracting features for sample: BraTS-MET-00278-000
# Fetching sample with ID: 250
# Extracting features for sample: BraTS-MET-00250-000
# Fetching sample with ID: 244
# Extracting features for sample: BraTS-MET-00244-000
# Fetching sample with ID: 126
# Extracting features for sample: BraTS-MET-00126-000
# Fetching sample with ID: 132
# Extracting features for sample: BraTS-MET-00132-000
# Fetching sample with ID: 133
# Extracting features for sample: BraTS-MET-00133-000
# Fetching sample with ID: 127
# Extracting features for sample: BraTS-MET-00127-000
# Fetching sample with ID: 245
# Extracting features for sample: BraTS-MET-00245-000
# Fetching sample with ID: 251
# Extracting features for sample: BraTS-MET-00251-000
# Fetching sample with ID: 286
# Extracting features for sample: BraTS-MET-00286-000
# Fetching sample with ID: 292
# Extracting features for sample: BraTS-MET-00292-000
# Fetching sample with ID: 90
# Extracting features for sample: BraTS-MET-00090-000
# Fetching sample with ID: 296
# Extracting features for sample: BraTS-MET-00296-000
# Fetching sample with ID: 282
# Extracting features for sample: BraTS-MET-00282-000
# Fetching sample with ID: 255
# Extracting features for sample: BraTS-MET-00255-000
# Fetching sample with ID: 241
# Extracting features for sample: BraTS-MET-00241-000
# Fetching sample with ID: 269
# Extracting features for sample: BraTS-MET-00269-000
# Fetching sample with ID: 309
# Extracting features for sample: BraTS-MET-00309-000
# Fetching sample with ID: 123
# Extracting features for sample: BraTS-MET-00123-000
# Fetching sample with ID: 137
# Extracting features for sample: BraTS-MET-00137-000
# Fetching sample with ID: 136
# Extracting features for sample: BraTS-MET-00136-000
# Fetching sample with ID: 122
# Extracting features for sample: BraTS-MET-00122-000
# Fetching sample with ID: 268
# Extracting features for sample: BraTS-MET-00268-000
# Fetching sample with ID: 240
# Extracting features for sample: BraTS-MET-00240-000
# Fetching sample with ID: 254
# Extracting features for sample: BraTS-MET-00254-000
# Fetching sample with ID: 283
# Extracting features for sample: BraTS-MET-00283-000
# Fetching sample with ID: 97
# Extracting features for sample: BraTS-MET-00097-000
# Fetching sample with ID: 281
# Extracting features for sample: BraTS-MET-00281-000
# Fetching sample with ID: 295
# Extracting features for sample: BraTS-MET-00295-000
# Fetching sample with ID: 242
# Extracting features for sample: BraTS-MET-00242-000
# Fetching sample with ID: 256
# Extracting features for sample: BraTS-MET-00256-000
# Fetching sample with ID: 134
# Extracting features for sample: BraTS-MET-00134-000
# Fetching sample with ID: 120
# Extracting features for sample: BraTS-MET-00120-000
# Fetching sample with ID: 108
# Extracting features for sample: BraTS-MET-00108-000
# Fetching sample with ID: 109
# Extracting features for sample: BraTS-MET-00109-000
# Fetching sample with ID: 121
# Extracting features for sample: BraTS-MET-00121-000
# Fetching sample with ID: 135
# Extracting features for sample: BraTS-MET-00135-000
# Fetching sample with ID: 243
# Extracting features for sample: BraTS-MET-00243-000
# Fetching sample with ID: 294
# Extracting features for sample: BraTS-MET-00294-000
# Fetching sample with ID: 280
# Extracting features for sample: BraTS-MET-00280-000
# Fetching sample with ID: 96
# Extracting features for sample: BraTS-MET-00096-000
# Fetching sample with ID: 224
# Extracting features for sample: BraTS-MET-00224-000
# Fetching sample with ID: 230
# Extracting features for sample: BraTS-MET-00230-000
# Fetching sample with ID: 191
# Extracting features for sample: BraTS-MET-00191-000
# Fetching sample with ID: 185
# Extracting features for sample: BraTS-MET-00185-000
# Fetching sample with ID: 152
# Extracting features for sample: BraTS-MET-00152-000
# Fetching sample with ID: 147
# Extracting features for sample: BraTS-MET-00147-000
# Fetching sample with ID: 153
# Extracting features for sample: BraTS-MET-00153-000
# Fetching sample with ID: 184
# Extracting features for sample: BraTS-MET-00184-000
# Fetching sample with ID: 190
# Extracting features for sample: BraTS-MET-00190-000
# Fetching sample with ID: 231
# Extracting features for sample: BraTS-MET-00231-000
# Fetching sample with ID: 225
# Extracting features for sample: BraTS-MET-00225-000
# Fetching sample with ID: 219
# Extracting features for sample: BraTS-MET-00219-000
# Fetching sample with ID: 233
# Extracting features for sample: BraTS-MET-00233-000
# Fetching sample with ID: 227
# Extracting features for sample: BraTS-MET-00227-000
# Fetching sample with ID: 192
# Extracting features for sample: BraTS-MET-00192-000
# Fetching sample with ID: 179
# Extracting features for sample: BraTS-MET-00179-000
# Fetching sample with ID: 145
# Extracting features for sample: BraTS-MET-00145-000
# Fetching sample with ID: 151
# Extracting features for sample: BraTS-MET-00151-000
# Fetching sample with ID: 150
# Extracting features for sample: BraTS-MET-00150-000
# Fetching sample with ID: 144
# Extracting features for sample: BraTS-MET-00144-000
# Fetching sample with ID: 178
# Extracting features for sample: BraTS-MET-00178-000
# Fetching sample with ID: 193
# Extracting features for sample: BraTS-MET-00193-000
# Fetching sample with ID: 187
# Extracting features for sample: BraTS-MET-00187-000
# Fetching sample with ID: 226
# Extracting features for sample: BraTS-MET-00226-000
# Fetching sample with ID: 232
# Extracting features for sample: BraTS-MET-00232-000
# Fetching sample with ID: 222
# Extracting features for sample: BraTS-MET-00222-000
# Fetching sample with ID: 183
# Extracting features for sample: BraTS-MET-00183-000
# Fetching sample with ID: 197
# Extracting features for sample: BraTS-MET-00197-000
# Fetching sample with ID: 140
# Extracting features for sample: BraTS-MET-00140-000
# Fetching sample with ID: 154
# Extracting features for sample: BraTS-MET-00154-000
# Fetching sample with ID: 169
# Extracting features for sample: BraTS-MET-00169-000
# Fetching sample with ID: 155
# Extracting features for sample: BraTS-MET-00155-000
# Fetching sample with ID: 141
# Extracting features for sample: BraTS-MET-00141-000
# Fetching sample with ID: 196
# Extracting features for sample: BraTS-MET-00196-000
# Fetching sample with ID: 182
# Extracting features for sample: BraTS-MET-00182-000
# Fetching sample with ID: 223
# Extracting features for sample: BraTS-MET-00223-000
# Fetching sample with ID: 237
# Extracting features for sample: BraTS-MET-00237-000
# Fetching sample with ID: 221
# Extracting features for sample: BraTS-MET-00221-000
# Fetching sample with ID: 235
# Extracting features for sample: BraTS-MET-00235-000
# Fetching sample with ID: 209
# Extracting features for sample: BraTS-MET-00209-000
# Fetching sample with ID: 194
# Extracting features for sample: BraTS-MET-00194-000
# Fetching sample with ID: 180
# Extracting features for sample: BraTS-MET-00180-000
# Fetching sample with ID: 157
# Extracting features for sample: BraTS-MET-00157-000
# Fetching sample with ID: 143
# Extracting features for sample: BraTS-MET-00143-000
# Fetching sample with ID: 142
# Extracting features for sample: BraTS-MET-00142-000
# Fetching sample with ID: 156
# Extracting features for sample: BraTS-MET-00156-000
# Fetching sample with ID: 181
# Extracting features for sample: BraTS-MET-00181-000
# Fetching sample with ID: 195
# Extracting features for sample: BraTS-MET-00195-000
# Fetching sample with ID: 208
# Extracting features for sample: BraTS-MET-00208-000
# Fetching sample with ID: 234
# Extracting features for sample: BraTS-MET-00234-000
# Fetching sample with ID: 220
# Extracting features for sample: BraTS-MET-00220-000
# Fetching sample with ID: 239
# Extracting features for sample: BraTS-MET-00239-000
# Fetching sample with ID: 205
# Extracting features for sample: BraTS-MET-00205-000
# Fetching sample with ID: 211
# Extracting features for sample: BraTS-MET-00211-000
# Fetching sample with ID: 198
# Extracting features for sample: BraTS-MET-00198-000
# Fetching sample with ID: 173
# Extracting features for sample: BraTS-MET-00173-000
# Fetching sample with ID: 167
# Extracting features for sample: BraTS-MET-00167-000
# Fetching sample with ID: 166
# Extracting features for sample: BraTS-MET-00166-000
# Fetching sample with ID: 172
# Extracting features for sample: BraTS-MET-00172-000
# Fetching sample with ID: 199
# Extracting features for sample: BraTS-MET-00199-000
# Fetching sample with ID: 210
# Extracting features for sample: BraTS-MET-00210-000
# Fetching sample with ID: 204
# Extracting features for sample: BraTS-MET-00204-000
# Fetching sample with ID: 238
# Extracting features for sample: BraTS-MET-00238-000
# Fetching sample with ID: 212
# Extracting features for sample: BraTS-MET-00212-000
# Fetching sample with ID: 206
# Extracting features for sample: BraTS-MET-00206-000
# Fetching sample with ID: 158
# Extracting features for sample: BraTS-MET-00158-000
# Fetching sample with ID: 164
# Extracting features for sample: BraTS-MET-00164-000
# Fetching sample with ID: 170
# Extracting features for sample: BraTS-MET-00170-000
# Fetching sample with ID: 171
# Extracting features for sample: BraTS-MET-00171-000
# Fetching sample with ID: 165
# Extracting features for sample: BraTS-MET-00165-000
# Fetching sample with ID: 159
# Extracting features for sample: BraTS-MET-00159-000
# Fetching sample with ID: 207
# Extracting features for sample: BraTS-MET-00207-000
# Fetching sample with ID: 213
# Extracting features for sample: BraTS-MET-00213-000
# Fetching sample with ID: 217
# Extracting features for sample: BraTS-MET-00217-000
# Fetching sample with ID: 203
# Extracting features for sample: BraTS-MET-00203-000
# Fetching sample with ID: 161
# Extracting features for sample: BraTS-MET-00161-000
# Fetching sample with ID: 175
# Extracting features for sample: BraTS-MET-00175-000
# Fetching sample with ID: 149
# Extracting features for sample: BraTS-MET-00149-000
# Fetching sample with ID: 148
# Extracting features for sample: BraTS-MET-00148-000
# Fetching sample with ID: 174
# Extracting features for sample: BraTS-MET-00174-000
# Fetching sample with ID: 160
# Extracting features for sample: BraTS-MET-00160-000
# Fetching sample with ID: 202
# Extracting features for sample: BraTS-MET-00202-000
# Fetching sample with ID: 216
# Extracting features for sample: BraTS-MET-00216-000
# Fetching sample with ID: 200
# Extracting features for sample: BraTS-MET-00200-000
# Fetching sample with ID: 214
# Extracting features for sample: BraTS-MET-00214-000
# Fetching sample with ID: 189
# Extracting features for sample: BraTS-MET-00189-000
# Fetching sample with ID: 176
# Extracting features for sample: BraTS-MET-00176-000
# Fetching sample with ID: 162
# Extracting features for sample: BraTS-MET-00162-000
# Fetching sample with ID: 163
# Extracting features for sample: BraTS-MET-00163-000
# Fetching sample with ID: 177
# Extracting features for sample: BraTS-MET-00177-000
# Fetching sample with ID: 188
# Extracting features for sample: BraTS-MET-00188-000
# Fetching sample with ID: 229
# Extracting features for sample: BraTS-MET-00229-000
# Fetching sample with ID: 215
# Extracting features for sample: BraTS-MET-00215-000
# Fetching sample with ID: 201
# Extracting features for sample: BraTS-MET-00201-000
# Fetching sample with ID: 299
# Extracting features for sample: BraTS-MET-00299-000
# Fetching sample with ID: 266
# Extracting features for sample: BraTS-MET-00266-000
# Fetching sample with ID: 272
# Extracting features for sample: BraTS-MET-00272-000
# Fetching sample with ID: 306
# Extracting features for sample: BraTS-MET-00306-000
# Fetching sample with ID: 138
# Extracting features for sample: BraTS-MET-00138-000
# Fetching sample with ID: 110
# Extracting features for sample: BraTS-MET-00110-000
# Fetching sample with ID: 104
# Extracting features for sample: BraTS-MET-00104-000
# Fetching sample with ID: 105
# Extracting features for sample: BraTS-MET-00105-000
# Fetching sample with ID: 111
# Extracting features for sample: BraTS-MET-00111-000
# Fetching sample with ID: 139
# Extracting features for sample: BraTS-MET-00139-000
# Fetching sample with ID: 307
# Extracting features for sample: BraTS-MET-00307-000
# Fetching sample with ID: 273
# Extracting features for sample: BraTS-MET-00273-000
# Fetching sample with ID: 267
# Extracting features for sample: BraTS-MET-00267-000
# Fetching sample with ID: 298
# Extracting features for sample: BraTS-MET-00298-000
# Fetching sample with ID: 98
# Extracting features for sample: BraTS-MET-00098-000
# Fetching sample with ID: 271
# Extracting features for sample: BraTS-MET-00271-000
# Fetching sample with ID: 305
# Extracting features for sample: BraTS-MET-00305-000
# Fetching sample with ID: 107
# Extracting features for sample: BraTS-MET-00107-000
# Fetching sample with ID: 113
# Extracting features for sample: BraTS-MET-00113-000
# Fetching sample with ID: 112
# Extracting features for sample: BraTS-MET-00112-000
# Fetching sample with ID: 106
# Extracting features for sample: BraTS-MET-00106-000
# Fetching sample with ID: 310
# Extracting features for sample: BraTS-MET-00310-000
# Fetching sample with ID: 304
# Extracting features for sample: BraTS-MET-00304-000
# Fetching sample with ID: 264
# Extracting features for sample: BraTS-MET-00264-000
# Fetching sample with ID: 270
# Extracting features for sample: BraTS-MET-00270-000
# Fetching sample with ID: 258
# Extracting features for sample: BraTS-MET-00258-000
# Fetching sample with ID: 89
# Extracting features for sample: BraTS-MET-00089-000
# Fetching sample with ID: 274
# Extracting features for sample: BraTS-MET-00274-000
# Fetching sample with ID: 260
# Extracting features for sample: BraTS-MET-00260-000
# Fetching sample with ID: 248
# Extracting features for sample: BraTS-MET-00248-000
# Fetching sample with ID: 300
# Extracting features for sample: BraTS-MET-00300-000
# Fetching sample with ID: 102
# Extracting features for sample: BraTS-MET-00102-000
# Fetching sample with ID: 116
# Extracting features for sample: BraTS-MET-00116-000
# Fetching sample with ID: 117
# Extracting features for sample: BraTS-MET-00117-000
# Fetching sample with ID: 301
# Extracting features for sample: BraTS-MET-00301-000
# Fetching sample with ID: 249
# Extracting features for sample: BraTS-MET-00249-000
# Fetching sample with ID: 275
# Extracting features for sample: BraTS-MET-00275-000
# Fetching sample with ID: 288
# Extracting features for sample: BraTS-MET-00288-000
# Fetching sample with ID: 263
# Extracting features for sample: BraTS-MET-00263-000
# Fetching sample with ID: 277
# Extracting features for sample: BraTS-MET-00277-000
# Fetching sample with ID: 303
# Extracting features for sample: BraTS-MET-00303-000
# Fetching sample with ID: 115
# Extracting features for sample: BraTS-MET-00115-000
# Fetching sample with ID: 129
# Extracting features for sample: BraTS-MET-00129-000
# Fetching sample with ID: 128
# Extracting features for sample: BraTS-MET-00128-000
# Fetching sample with ID: 100
# Extracting features for sample: BraTS-MET-00100-000
# Fetching sample with ID: 114
# Extracting features for sample: BraTS-MET-00114-000
# Fetching sample with ID: 302
# Extracting features for sample: BraTS-MET-00302-000
# Fetching sample with ID: 276
# Extracting features for sample: BraTS-MET-00276-000
# Fetching sample with ID: 262
# Extracting features for sample: BraTS-MET-00262-000
# Fetching sample with ID: 289
# Extracting features for sample: BraTS-MET-00289-000

# %% [markdown]
# ### Store to Dataframe and merge with label data

# %%
df = pd.DataFrame(features)
df = df.astype(float)
df = pd.merge(df, label, how='left', on='BraTS_MET_ID')
# feature_output_filename = dataset_folder/Path('features')/Path(params_file_name)
feature_output_filename = os.path.join(dataset_folder, "features", f'{params_file_name}.pkl')
pd.to_pickle(df, feature_output_filename)
print(f"Stored dataset {feature_output_filename} to pickle")
# Out:
# Stored dataset /Users/stelios/workspace/stelios/pyradiomics/v2/dataset/features/params_1.pkl to pickle

# %%
df
# Out:
#      original_shape_Elongation  original_shape_Flatness  \
# 0                     0.743201                 0.342911
# 1                     0.786585                 0.470726
# 2                     0.804832                 0.676209
# 3                     0.873655                 0.642660
# 4                     0.755626                 0.352583
# ..                         ...                      ...
# 195                   0.666965                 0.401032
# 196                   0.775088                 0.509471
# 197                   0.273180                 0.166535
# 198                   0.752908                 0.517420
# 199                   0.260107                 0.156114
#
#      original_shape_LeastAxisLength  original_shape_MajorAxisLength  \
# 0                         14.042317                       40.950293
# 1                         39.115621                       83.096308
# 2                         50.273607                       74.346296
# 3                          8.244739                       12.829073
# 4                         39.270515                      111.379385
# ..                              ...                             ...
# 195                       58.450399                      145.749926
# 196                       21.146181                       41.506154
# 197                       27.351589                      164.239088
# 198                       38.664430                       74.725478
# 199                        5.780493                       37.027325
#
#     original_shape_Maximum2DDiameterColumn  \
# 0                        34.92849839314596
# 1                        76.02631123499285
# 2                        75.28612089887484
# 3                       12.806248474865697
# 4                        104.6900186264192
# ..                                     ...
# 195                     128.06248474865697
# 196                      38.41874542459709
# 197                     116.01724009818541
# 198                      76.94153624668537
# 199                     18.439088914585774
#
#     original_shape_Maximum2DDiameterRow original_shape_Maximum2DDiameterSlice  \
# 0                     40.24922359499622                     34.92849839314596
# 1                     86.55634003352961                     94.76286192385707
# 2                      92.5418824100742                     95.03683496413377
# 3                    14.422205101855956                    12.649110640673518
# 4                    112.44554237496477                    105.84894897919393
# ..                                  ...                                   ...
# 195                  147.95945390545344                      154.983870128475
# 196                   45.65084884205331                    42.190046219457976
# 197                   75.07329751649384                     72.80109889280519
# 198                   88.81441324469807                     74.96665925596525
# 199                  10.770329614269007                      8.94427190999916
#
#     original_shape_Maximum3DDiameter original_shape_MeshVolume  \
# 0                  42.37924020083418        3955.3333333333335
# 1                   95.5405672999695        109024.66666666667
# 2                  96.72641831474998                  139839.0
# 3                 15.620499351813308         731.3333333333334
# 4                 119.43198901466893        119523.33333333333
# ..                               ...                       ...
# 195               164.40194646049662        107098.66666666667
# 196                48.78524367060187        17172.666666666668
# 197                118.4736257569591        23359.666666666668
# 198                88.90444308357148                  102216.0
# 199               33.823069050575526         309.6666666666667
#
#      original_shape_MinorAxisLength  ... Death Infratentorial ET_num  Nec_num  \
# 0                         30.434283  ...   0.0            1.0    3.0      0.0
# 1                         65.362292  ...   0.0            0.0    1.0      1.0
# 2                         59.836279  ...   1.0            0.0    1.0      1.0
# 3                         11.208178  ...   1.0            1.0    1.0      1.0
# 4                         84.161214  ...   0.0            0.0    4.0      4.0
# ..                              ...  ...   ...            ...    ...      ...
# 195                       97.210169  ...   1.0            1.0   47.0      2.0
# 196                       32.170902  ...   0.0            0.0    1.0      1.0
# 197                       44.866798  ...   1.0            0.0    3.0      2.0
# 198                       56.261406  ...   0.0            0.0    1.0      1.0
# 199                        9.631073  ...   0.0            1.0    3.0      3.0
#
#     Edema_num ET_vol Nec_vol Edema_vol Nec_ET_ratio Edema_ET_ratio
# 0         3.0  0.458   0.000     3.469     0.000000       7.574236
# 1         1.0  3.715   1.298   104.020     0.258927      20.750050
# 2         1.0  9.752   6.160   124.244     0.387129       7.808195
# 3         1.0  0.345   0.071     0.425     0.170673       1.021635
# 4         4.0  5.026   0.933   113.765     0.156570      19.091290
# ..        ...    ...     ...       ...          ...            ...
# 195      30.0  9.563   0.152    99.068     0.015646      10.197427
# 196       1.0  0.885   0.474    16.054     0.348786      11.813098
# 197       3.0  1.598   0.130    21.638     0.075231      12.521991
# 198       1.0  2.147   0.467    99.474     0.178653      38.054323
# 199       0.0  0.337   0.052     0.000     0.133676       0.000000
#
# [200 rows x 1215 columns]
